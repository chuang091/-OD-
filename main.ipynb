# %%
import csv
import os
import pandas as pd

# %%
df = pd.read_csv('臺北捷運每日分時各站OD流量統計資料_202207.csv') #檔案名稱
#母資料

# %%
df
# Out:
#                  日期  時段      進站      出站  人次
# 0        2022-07-01   0    松山機場    松山機場   0
# 1        2022-07-01   0    松山機場    中山國中   0
# 2        2022-07-01   0    松山機場    南京復興   0
# 3        2022-07-01   0    松山機場    忠孝復興   0
# 4        2022-07-01   0    松山機場      大安   1
# ...             ...  ..     ...     ...  ..
# 9218806  2022-07-31  23  新北產業園區      板新   4
# 9218807  2022-07-31  23  新北產業園區     Y板橋   7
# 9218808  2022-07-31  23  新北產業園區    新埔民生   7
# 9218809  2022-07-31  23  新北產業園區      幸福   1
# 9218810  2022-07-31  23  新北產業園區  新北產業園區   1
#
# [9218811 rows x 5 columns]

# %%
date=[]
for i in range(1,32):
    if i <10: date.append('2022-07-0{}'.format(i)) #日期記得改
    else: date.append('2022-07-{}'.format(i))
date #獲取日期列表
# Out:
# ['2022-07-01',
#  '2022-07-02',
#  '2022-07-03',
#  '2022-07-04',
#  '2022-07-05',
#  '2022-07-06',
#  '2022-07-07',
#  '2022-07-08',
#  '2022-07-09',
#  '2022-07-10',
#  '2022-07-11',
#  '2022-07-12',
#  '2022-07-13',
#  '2022-07-14',
#  '2022-07-15',
#  '2022-07-16',
#  '2022-07-17',
#  '2022-07-18',
#  '2022-07-19',
#  '2022-07-20',
#  '2022-07-21',
#  '2022-07-22',
#  '2022-07-23',
#  '2022-07-24',
#  '2022-07-25',
#  '2022-07-26',
#  '2022-07-27',
#  '2022-07-28',
#  '2022-07-29',
#  '2022-07-30',
#  '2022-07-31']

# %%
stationa=df['進站']
stationa=list(set(list(stationa)))
stationa #獲取站點列表
# Out:
# ['府中',
#  '萬隆',
#  '頂溪',
#  '明德',
#  '新店',
#  '關渡',
#  '忠孝新生',
#  '忠孝復興',
#  '東門',
#  '後山埤',
#  '龍山寺',
#  '中山國小',
#  '頂埔',
#  '辛亥',
#  '大湖公園',
#  '大橋頭站',
#  '菜寮',
#  '永安市場',
#  '新莊',
#  '松江南京',
#  '市政府',
#  '景美',
#  '台北101/世貿',
#  '芝山',
#  '頭前庄',
#  '動物園',
#  '南港軟體園區',
#  '台北車站',
#  '劍潭',
#  '新北投',
#  '橋和',
#  '小南門',
#  '十四張',
#  '六張犁',
#  '大安森林公園',
#  '東湖',
#  '內湖',
#  '昆陽',
#  '中山',
#  '台電大樓',
#  '三民高中',
#  '台北小巨蛋',
#  '永寧',
#  '港墘',
#  '大坪林',
#  '新北產業園區',
#  '小碧潭',
#  '南京三民',
#  '信義安和',
#  '七張',
#  '三重國小',
#  '丹鳳',
#  '台北橋',
#  '景平',
#  '紅樹林',
#  '行天宮',
#  '國父紀念館',
#  '幸福',
#  '北門',
#  '忠義',
#  '大直',
#  '板新',
#  '文德',
#  '中正紀念堂',
#  '北投',
#  '蘆洲',
#  '麟光',
#  '台大醫院',
#  '唭哩岸',
#  '中原',
#  'BL板橋',
#  '松山機場',
#  '迴龍',
#  '南京復興',
#  '景安',
#  '象山',
#  '圓山',
#  '竹圍',
#  '古亭',
#  '秀朗橋',
#  '南勢角',
#  '大安',
#  '劍南路',
#  '科技大樓',
#  '徐匯中學',
#  '永春',
#  '善導寺',
#  'Y板橋',
#  '萬芳醫院',
#  '民權西路',
#  '輔大',
#  '忠孝敦化',
#  '南港展覽館',
#  '江子翠',
#  '新埔',
#  '先嗇宮',
#  '新店區公所',
#  '雙連',
#  '新埔民生',
#  '西湖',
#  '西門',
#  '萬芳社區',
#  '南港',
#  '石牌',
#  '葫洲',
#  '公館',
#  '海山',
#  '亞東醫院',
#  '中和',
#  '淡水',
#  '土城',
#  '奇岩',
#  '中山國中',
#  '復興崗',
#  '木柵',
#  '三和國中',
#  '三重',
#  '松山',
#  '士林']

# %%
def spli(station):
    path = station
    if not os.path.isdir(path):os.mkdir(path)
    if not os.path.isdir("{}/出站".format(path)):os.mkdir("{}/出站".format(path))
    if not os.path.isdir("{}/進站".format(path)):os.mkdir("{}/進站".format(path)) #建立資料夾
    def exit(x,y):
        a=(df[(df['{}'.format(x)] == station)]) #擷取資料
        for i in date:
            b=(a[(a['日期'] == i)]) #擷取日期
            b.reset_index(inplace = True,drop=True)
            data = pd.DataFrame(columns=stationa,index=list(range(24)))
            for j in stationa: #iterate站點時段：建立最後的dataframe
                c=(b[(b[y] == j)])
                c.set_index(["時段"], inplace = True)
                for k in range(24):
                    try: data.loc[k,j]=(c.loc[k]["人次"]) #賦值
                    except KeyError as err:pass #忽略空值
            data = data.rename_axis('time') #索引欄位命名
            data.to_csv("{}/{}/{}_{}.csv".format(path,x,i,x),encoding='Big5') #將dataframe匯出
    exit("進站","出站") #以進站為角度
    exit("出站","進站") #以出站為角度
# i 日期 j 站點 k 小時

# %%
spli("台北車站") #站點名稱 (可用for loop 跑整個台北捷運站)
